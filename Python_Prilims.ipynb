# %% [markdown]
# # Python Data Types, Variables

# %%
import numpy as np

# %%
rng = np.random.default_rng(seed=42)

# %%
rng.integers(low=10,high=100,size = 5)

# %%
rng.uniform(low=55.7,high = 85.7,size = 10).round(2)

# %% [markdown]
# ## Task 1:
# - Calculate Revenue given Unit Price and  Quantity

# %% [markdown]
# ## Task 2:
# - Calculate Profit given cost price and selling price

# %% [markdown]
# ## Task 3:
# - Calculate revenue given unit price of multiple products and their purchase quantity

# %%
lst_unit_price = rng.integers(low=1000,high=10000,size = 20).tolist()

# %%
lst_purchase_quantity = rng.integers(low=2,high=10,size=20).tolist()

# %%
list(zip(lst_unit_price,lst_purchase_quantity))

# %% [markdown]
# ## Task 4 :
# - Calculate revenue for a each month given daily revenue

# %%
dict_revenue = {
    "Jan":rng.integers(low=1000,high=10000,size = 20).tolist(),
    "Feb":rng.integers(low=1000,high=10000,size = 20).tolist(),
    "March":rng.integers(low=1000,high=10000,size = 20).tolist(),
    "April":rng.integers(low=1000,high=10000,size = 20).tolist(),
    "May":rng.integers(low=1000,high=10000,size = 20).tolist()
}

# %% [markdown]
# ## Task 5
# - Calculate Profit margin given Price and Quantity
