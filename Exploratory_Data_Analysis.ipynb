# %% [markdown]
# # Load, Clean and Explore (UCI Online Retail)
#
# **Goal:** Practice importing,cleaning,aggregating and visualising transactional data to answer business questions
#
# **Dataset:** 'Online Retail.xlsx' from UCI Machine Learning Repository
#
# **url**: https://archive.ics.uci.edu/dataset/352/online+retail

# %%
# Imports required for the tasks

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set()
plt.rcParams['figure.figsize']=(10,4)

# %%
# Load data from the path  via left Files pane 
PATH = 'datasets/Online Retail.xlsx'
df_online = pd.read_excel(PATH)

# %% [markdown]
# ## $\checkmark$Task 1 - Basic Inspection of the Dataset
# - Use **'head()/tail()'** ,**'info()'** , **'describe()'**
# - Know how to select **column/columns**
# - Count unique values for a column
# - Identify columns with missing data

# %% [markdown]
# ## $\checkmark$ Task 2 - Clean the data
# - Remove cancellation invoices (InvoicesNo starting with 'C')
# - Drop rows with null **CustomerID**
# - Create **TotalPrice** = **Quantity** * **UnitPrice**
# - Convert **InvoiceDate** to datetime and create **InvoiceMonth**

# %% [markdown]
# ## $\checkmark$ Task 3 - KPIs
# - Monthly revenue
# - Average order value (AOV)
# - Repeat customers (% of customers with $\ge$2 invoices)

# %% [markdown]
# ## $\checkmark$ Visualizations
# Create
# 1) Monthly revenue line chart
# 2) Top 10 products by revenue
# 3) Country revenue share (bar/pie)
# 4) One additional chart of your choice
